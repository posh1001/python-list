# %%
to_do_list = ["Buy Groceries", "Clean the house", "Pay bills"]

to_do_list.append("Schedule meetings")
to_do_list.append("Go to the gym")

to_do_list.remove("Clean the house")

if "Pay bills" in to_do_list:
    print("Don't forget to pay your bills")

print("To do list reminder")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Don't forget to pay your bills
# To do list reminder
# -Buy Groceries
# -Pay bills
# -Schedule meetings
# -Go to the gym

# %%
grades = [85, 92, 78, 90, 88]

## Adding a new grade
grades.append(45)

## Calculating the average grade
average_grade = sum(grades) / len(grades)
print(f"Average grade: {average_grade:.2f}")

# Finding the highest and the lowest grade
highest_grade = max(grades)
lowest_grade = min(grades)

print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average grade: 79.67
# Highest Grade: 92
# Lowest Grade: 45

# %%
# Managing inventory
inventories = ["apples", "banana", "oranges", "paw paw"]

# Add a new inventory
inventories.append("strawberry")

#Removing an inventory
inventories.remove("paw paw")

# Checking if orange is in the store
item = "oranges"
if item in inventories:
    print(f"{item} are in stock")
else:
    print(f"{item} are out of stock.")

# Printing inventory list
print("Inventory List:")
for item in inventories:
    print(f"- {item}")
# Out:
# oranges are in stock
# Inventory List:
# - apples
# - banana
# - oranges
# - strawberry

# %%
# Collecting user feedback
feedback = ["Great service!", "Very satisfied", "Could be better", "Excellent experience"]

# Adding new feedback
feedback.append("Not happy with the service")

# Counting specific feedback
positive_feedback_count = sum(1 for comment in feedback if "great"
in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback Count: {positive_feedback_count}")

#Printing all feedback
print("User Feedback:")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count: 2
# User Feedback:
# - Great service!
# - Very satisfied
# - Could be better
# - Excellent experience
# - Not happy with the service
